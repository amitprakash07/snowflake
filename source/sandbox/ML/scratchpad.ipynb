# %%
import torch

# %%
print(torch.cuda.is_available())
# Out:
# False

# %% [markdown]
# ##### Demo for usage of SumPy package, and math plot

# %%
from sympy import *

x = symbols('x')
f = (2*x) - 1 

plot(f)

# %%
x = symbols('x')
f = x**2

plot(f)

# %%
from sympy import *
from sympy.plotting import plot3d

x, y = symbols('x y')
f = 2*x + 3*y
plot3d(f)

# %%
summation = sum(i for i in range(3,10))
print(summation)
# Out:
# 42

# %%
data = [1,2,3,4]

summation = sum(2*data[i] for i in range(0, len(data)))
print(summation)
# Out:
# 20

# %%
from sympy import *

i,n = symbols('i n')

# iterate each element i from 1 to n,
# then multiply and sum
summation = Sum(2*i,(i,1,n))

# specify n as 5,
# iterating the numbers 1 through 5
up_to_5 = summation.subs(n, 5)
print(up_to_5.doit()) # 30
# Out:
# 30

# %%
from sympy import *

x = symbols('x')
expr = x**2 / x**5
print(expr) # x**(-3)
# Out:
# x**(-3)

# %%
from math import log

# 2 raised to what power gives me 8?
x = log(8, 2)
print(x) # prints 3.0

x = log(8) ## no base, defaults to e
print(x)
# Out:
# 3.0
# 2.0794415416798357

# %%
x = symbols('x')
f = 1/x
plot(f)

result = limit(f, x, oo)
print(result)
# Out:
# 0

# %%
from sympy import *

n = symbols('n')
f = (1 + (1/n))**n
result = limit(f, n, oo)

print(result) # E
print(result.evalf()) # 2.71828182845905
# Out:
# E
# 2.71828182845905

# %%
from sympy import *

# Declare 'x' to SymPy
x = symbols('x')

# Now just use Python syntax to declare function
f = x**2

# Calculate the derivative of the function
dx_f = diff(f)
print(dx_f) # prints 2*x

# Calculate the slope at x = 2
print(dx_f.subs(x,2)) # prints 4
# Out:
# 2*x
# 4

# %%
from sympy import *
from sympy.plotting import plot3d

# Declare x and y to SymPy
x,y = symbols('x y')

# Now just use Python syntax to declare function
f = 2*x**3 + 3*y**3

# Calculate the partial derivatives for x and y
dx_f = diff(f, x)
dy_f = diff(f, y)

print(dx_f) # prints 6*x**2
print(dy_f) # prints 9*y**2

# plot the function
plot3d(f)
# Out:
# 6*x**2
# 9*y**2
